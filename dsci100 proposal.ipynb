# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
heart_data <- read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data", col_names = FALSE) |>
    rename("age"= X1, "sex" = X2, "chest_pain" = X3, "trestbps" = X4, "chol" = X5, "fasting_bs" = X6, "restecg" = X7, "max_heart_rate" = X8, "exang" = X9, "old_peak" = X10, "peak_slope" = X11, "ca" = X12, "thal" = X13, "predicted" = X14) |>
    mutate(sex = recode(sex, "1" = "male", "0" = "female")) |>
    mutate(chest_pain = recode(chest_pain, "1" = "typical_angina", "2" = "atypical_angina", "3" = "non_anginal_pain", "4" = "asymptomatic")) |>
    mutate(trestbps = as.integer(trestbps)) |>
    mutate(chol = as.integer(chol)) |>
    mutate(fasting_bs = recode(fasting_bs, "1" = "over_120", "0" = "under_120")) |>
    mutate(restecg = recode(restecg, "0" = "normal", "1" = "abnormal", "2" = "hypertrophy")) |>
    mutate(max_heart_rate = as.integer(max_heart_rate)) |>
    mutate(old_peak = as.numeric(old_peak)) |>
    mutate(ca = as.integer(ca)) |>
    mutate(exang = recode(exang, "0" = "no", "1" = "yes")) |>
    mutate(peak_slope = as.integer(peak_slope)) |>
    mutate(thal = recode(thal, "3.0" = "normal", "6.0" = "fixed_defect", "7.0" = "reversable_defect")) |>
    mutate(predicted = as.factor(predicted)) |>
    mutate(predicted = recode(predicted, "0" = "no_cvd", "1" = "cvd", "2" = "cvd", "3" = "cvd", "4" = "cvd")) |>
    na.omit()


heart_recipe <- recipe(predicted ~ age + sex + chest_pain + trestbps + chol + max_heart_rate, data = heart_data) |>
    step_scale(all_predictors()) |>
        step_center(all_predictors())

    


# Based on a patient's physical properities, can we consistently predict their CVD diagnosis 
    
        
heart_data
# Out:
# Rows: 303 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): X12, X13
# dbl (12): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message in mask$eval_all_mutate(quo):
# “NAs introduced by coercion”
#     age sex    chest_pain       trestbps chol fasting_bs restecg
# 1   63  male   typical_angina   145      233  over_120   hypertrophy
# 2   67  male   asymptomatic     160      286  under_120  hypertrophy
# 3   67  male   asymptomatic     120      229  under_120  hypertrophy
# 4   37  male   non_anginal_pain 130      250  under_120  normal
# 5   41  female atypical_angina  130      204  under_120  hypertrophy
# 6   56  male   atypical_angina  120      236  under_120  normal
# 7   62  female asymptomatic     140      268  under_120  hypertrophy
# 8   57  female asymptomatic     120      354  under_120  normal
# 9   63  male   asymptomatic     130      254  under_120  hypertrophy
# 10  53  male   asymptomatic     140      203  over_120   hypertrophy
# 11  57  male   asymptomatic     140      192  under_120  normal
# 12  56  female atypical_angina  140      294  under_120  hypertrophy
# 13  56  male   non_anginal_pain 130      256  over_120   hypertrophy
# 14  44  male   atypical_angina  120      263  under_120  normal
# 15  52  male   non_anginal_pain 172      199  over_120   normal
# 16  57  male   non_anginal_pain 150      168  under_120  normal
# 17  48  male   atypical_angina  110      229  under_120  normal
# 18  54  male   asymptomatic     140      239  under_120  normal
# 19  48  female non_anginal_pain 130      275  under_120  normal
# 20  49  male   atypical_angina  130      266  under_120  normal
# 21  64  male   typical_angina   110      211  under_120  hypertrophy
# 22  58  female typical_angina   150      283  over_120   hypertrophy
# 23  58  male   atypical_angina  120      284  under_120  hypertrophy
# 24  58  male   non_anginal_pain 132      224  under_120  hypertrophy
# 25  60  male   asymptomatic     130      206  under_120  hypertrophy
# 26  50  female non_anginal_pain 120      219  under_120  normal
# 27  58  female non_anginal_pain 120      340  under_120  normal
# 28  66  female typical_angina   150      226  under_120  normal
# 29  43  male   asymptomatic     150      247  under_120  normal
# 30  40  male   asymptomatic     110      167  under_120  hypertrophy
# ⋮   ⋮   ⋮      ⋮                ⋮        ⋮    ⋮          ⋮
# 270 66  male   asymptomatic     160      228  under_120  hypertrophy
# 271 46  male   asymptomatic     140      311  under_120  normal
# 272 71  female asymptomatic     112      149  under_120  normal
# 273 59  male   typical_angina   134      204  under_120  normal
# 274 64  male   typical_angina   170      227  under_120  hypertrophy
# 275 66  female non_anginal_pain 146      278  under_120  hypertrophy
# 276 39  female non_anginal_pain 138      220  under_120  normal
# 277 57  male   atypical_angina  154      232  under_120  hypertrophy
# 278 58  female asymptomatic     130      197  under_120  normal
# 279 57  male   asymptomatic     110      335  under_120  normal
# 280 47  male   non_anginal_pain 130      253  under_120  normal
# 281 55  female asymptomatic     128      205  under_120  abnormal
# 282 35  male   atypical_angina  122      192  under_120  normal
# 283 61  male   asymptomatic     148      203  under_120  normal
# 284 58  male   asymptomatic     114      318  under_120  abnormal
# 285 58  female asymptomatic     170      225  over_120   hypertrophy
# 286 56  male   atypical_angina  130      221  under_120  hypertrophy
# 287 56  male   atypical_angina  120      240  under_120  normal
# 288 67  male   non_anginal_pain 152      212  under_120  hypertrophy
# 289 55  female atypical_angina  132      342  under_120  normal
# 290 44  male   asymptomatic     120      169  under_120  normal
# 291 63  male   asymptomatic     140      187  under_120  hypertrophy
# 292 63  female asymptomatic     124      197  under_120  normal
# 293 41  male   atypical_angina  120      157  under_120  normal
# 294 59  male   asymptomatic     164      176  over_120   hypertrophy
# 295 57  female asymptomatic     140      241  under_120  normal
# 296 45  male   typical_angina   110      264  under_120  normal
# 297 68  male   asymptomatic     144      193  over_120   normal
# 298 57  male   asymptomatic     130      131  under_120  normal
# 299 57  female atypical_angina  130      236  under_120  hypertrophy
#     max_heart_rate exang old_peak peak_slope ca thal              predicted
# 1   150            no    2.3      3          0  fixed_defect      no_cvd
# 2   108            yes   1.5      2          3  normal            cvd
# 3   129            yes   2.6      2          2  reversable_defect cvd
# 4   187            no    3.5      3          0  normal            no_cvd
# 5   172            no    1.4      1          0  normal            no_cvd
# 6   178            no    0.8      1          0  normal            no_cvd
# 7   160            no    3.6      3          2  normal            cvd
# 8   163            yes   0.6      1          0  normal            no_cvd
# 9   147            no    1.4      2          1  reversable_defect cvd
# 10  155            yes   3.1      3          0  reversable_defect cvd
# 11  148            no    0.4      2          0  fixed_defect      no_cvd
# 12  153            no    1.3      2          0  normal            no_cvd
# 13  142            yes   0.6      2          1  fixed_defect      cvd
# 14  173            no    0.0      1          0  reversable_defect no_cvd
# 15  162            no    0.5      1          0  reversable_defect no_cvd
# 16  174            no    1.6      1          0  normal            no_cvd
# 17  168            no    1.0      3          0  reversable_defect cvd
# 18  160            no    1.2      1          0  normal            no_cvd
# 19  139            no    0.2      1          0  normal            no_cvd
# 20  171            no    0.6      1          0  normal            no_cvd
# 21  144            yes   1.8      2          0  normal            no_cvd
# 22  162            no    1.0      1          0  normal            no_cvd
# 23  160            no    1.8      2          0  normal            cvd
# 24  173            no    3.2      1          2  reversable_defect cvd
# 25  132            yes   2.4      2          2  reversable_defect cvd
# 26  158            no    1.6      2          0  normal            no_cvd
# 27  172            no    0.0      1          0  normal            no_cvd
# 28  114            no    2.6      3          0  normal            no_cvd
# 29  171            no    1.5      1          0  normal            no_cvd
# 30  114            yes   2.0      2          0  reversable_defect cvd
# ⋮   ⋮              ⋮     ⋮        ⋮          ⋮  ⋮                 ⋮
# 270 138            no    2.3      1          0  fixed_defect      no_cvd
# 271 120            yes   1.8      2          2  reversable_defect cvd
# 272 125            no    1.6      2          0  normal            no_cvd
# 273 162            no    0.8      1          2  normal            cvd
# 274 155            no    0.6      2          0  reversable_defect no_cvd
# 275 152            no    0.0      2          1  normal            no_cvd
# 276 152            no    0.0      2          0  normal            no_cvd
# 277 164            no    0.0      1          1  normal            cvd
# 278 131            no    0.6      2          0  normal            no_cvd
# 279 143            yes   3.0      2          1  reversable_defect cvd
# 280 179            no    0.0      1          0  normal            no_cvd
# 281 130            yes   2.0      2          1  reversable_defect cvd
# 282 174            no    0.0      1          0  normal            no_cvd
# 283 161            no    0.0      1          1  reversable_defect cvd
# 284 140            no    4.4      3          3  fixed_defect      cvd
# 285 146            yes   2.8      2          2  fixed_defect      cvd
# 286 163            no    0.0      1          0  reversable_defect no_cvd
# 287 169            no    0.0      3          0  normal            no_cvd
# 288 150            no    0.8      2          0  reversable_defect cvd
# 289 166            no    1.2      1          0  normal            no_cvd
# 290 144            yes   2.8      3          0  fixed_defect      cvd
# 291 144            yes   4.0      1          2  reversable_defect cvd
# 292 136            yes   0.0      2          0  normal            cvd
# 293 182            no    0.0      1          0  normal            no_cvd
# 294  90            no    1.0      2          2  fixed_defect      cvd
# 295 123            yes   0.2      2          0  reversable_defect cvd
# 296 132            no    1.2      2          0  reversable_defect cvd
# 297 141            no    3.4      2          2  reversable_defect cvd
# 298 115            yes   1.2      2          1  reversable_defect cvd
# 299 174            no    0.0      2          1  normal            cvd
